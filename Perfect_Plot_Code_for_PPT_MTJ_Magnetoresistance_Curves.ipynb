# %% [markdown]
# <a href="https://colab.research.google.com/github/OJB-Quantum/Notebooks/blob/main/Perfect_Plot_Code_for_PPT_MTJ_Magnetoresistance_Curves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DZ_255_MTJ = pd.read_excel('FP_DZ_255_MTJ.xlsx') # taken from real data set, exported from LABVIEW on a PC interfaced with the point-probe measurement setup.

# %%
DZ_255_MTJ
# Out:
#      field  current   Voltage (V)  resistance
# 0     -2.5  0.000008     0.004095  511.860741
# 1     -2.4  0.000008     0.004095  511.921375
# 2     -2.3  0.000008     0.004096  512.029634
# 3     -2.2  0.000008     0.004098  512.229836
# 4     -2.1  0.000008     0.004098  512.307748
# ..     ...       ...          ...         ...
# 97    -2.1  0.000008     0.004106  513.193719
# 98    -2.2  0.000008     0.004103  512.825102
# 99    -2.3  0.000008     0.004101  512.681083
# 100   -2.4  0.000008     0.004100  512.473213
# 101   -2.5  0.000008     0.004099  512.359335
#
# [102 rows x 4 columns]

# %%
# Use this command to recover default matplotlib settings in case seaborn style was modified
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
plt.style.use('seaborn-poster')

# %%
plt.style.use('seaborn-white')

# %%
plt.style.use('seaborn-dark-palette')

# %%
fig = plt.gcf()
fig.set_size_inches(7,4.9)
plt.plot(DZ_255_MTJ.field, DZ_255_MTJ.resistance)
plt.xlabel('Field Voltage (V)')
plt.ylabel('Magnetoresistance (Ω)')
plt.show()

# %%
# k- = black lines
# r- = red lines
# g- = green lines
# b- = blue lines
# ko- = black dotted lines
# ro- = red dotted lines
# go- = green dotted lines
# bo- = blue dotted lines
# Changing line width >>>   plt.plot(x , y, linewidth = 4)
# plt.title ('Insert Title Here') <<<<(or)>>>> plt.title ('$Insert $ $ Title $ $ Here$',fontsize = 14)
# plt.xlabel(r'$X Title$' , fontsize = 18)
