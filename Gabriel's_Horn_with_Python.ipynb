# %% [markdown]
# <a href="https://colab.research.google.com/github/OJB-Quantum/Notebooks-for-Ideas/blob/main/Gabriel's_Horn_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Gabriel's Horn without grid lines

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Onri prefers using rcParams to increase the quality of all plots to be higher than the default settings.
# This only needs to be done once at beginning of every Jupyter Notebook.
plt.rcParams['figure.dpi'] = 200

def gabriels_horn():
    # Define x values from 1 to 10 (finite truncation for visualization)
    x = np.linspace(1, 10, 300)
    y = 1 / x  # Function y = 1/x

    # Create theta values for rotation
    theta = np.linspace(0, 2*np.pi, 100)

    # Create a meshgrid for revolution
    X, T = np.meshgrid(x, theta)
    Y = 1 / X
    Z = Y * np.sin(T)
    Y = Y * np.cos(T)

    # Plot the surface
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, color='b', alpha=0.6, edgecolor='none')

    # Remove grid lines
    ax.grid(False)

    # Labels and title
    ax.set_xlabel("X-axis")
    ax.set_ylabel("Y-axis")
    ax.set_zlabel("Z-axis")
    ax.set_title("Gabriel's Horn")

    # Display the plot
    plt.show()

# Run visualization
gabriels_horn()

# %%
# Gabriel's Horn with grid lines

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def gabriels_horn():
    # Define x values from 1 to 10 (finite truncation for visualization)
    x = np.linspace(1, 10, 300)
    y = 1 / x  # Function y = 1/x

    # Create theta values for rotation
    theta = np.linspace(0, 2*np.pi, 100)

    # Create a meshgrid for revolution
    X, T = np.meshgrid(x, theta)
    Y = 1 / X
    Z = Y * np.sin(T)
    Y = Y * np.cos(T)

    # Plot the surface
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, color='b', alpha=0.6, edgecolor='none')

    # Labels and title
    ax.set_xlabel("X-axis")
    ax.set_ylabel("Y-axis")
    ax.set_zlabel("Z-axis")
    ax.set_title("Gabriel's Horn")

    # Display the plot
    plt.show()

# Run visualization
gabriels_horn()
